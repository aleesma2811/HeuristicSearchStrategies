# %%
pip install pillow
# Out:
# Requirement already satisfied: pillow in c:\users\efren\documents\github\projects\venvheuristicsearchstrategies\lib\site-packages (10.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\efren\documents\github\projects\venvheuristicsearchstrategies\lib\site-packages (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\efren\documents\github\projects\venvheuristicsearchstrategies\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\efren\documents\github\projects\venvheuristicsearchstrategies\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\efren\documents\github\projects\venvheuristicsearchstrategies\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\efren\documents\github\projects\venvheuristicsearchstrategies\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.21 in c:\users\efren\documents\github\projects\venvheuristicsearchstrategies\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\efren\documents\github\projects\venvheuristicsearchstrategies\lib\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\efren\documents\github\projects\venvheuristicsearchstrategies\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\efren\documents\github\projects\venvheuristicsearchstrategies\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\efren\documents\github\projects\venvheuristicsearchstrategies\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\efren\documents\github\projects\venvheuristicsearchstrategies\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import rompecocosSolver
import buscaCaminosSolver
import tkinter as tk
import time
from PIL import Image, ImageTk
import matplotlib.pyplot as plt

# %%
# FUNCIONES


#---------------------------------------------------------------------------------------------------------------------------------------------------------------
def mostrar_rompecocos():
    # Mostrar la imagen del juego "Rompecocos"
    rompecocos = Image.open("rompecocos.jpg")
    rompecocos = rompecocos.resize((300, 300), Image.LANCZOS)
    rompecocos = ImageTk.PhotoImage(rompecocos)
    label_graf.configure(image=rompecocos)
    label_graf.image = rompecocos
    ocultar_botones()
    mostrar_botones15()

def mostrar_buscacaminos():
    # Mostrar la imagen del juego "Busca Caminos"
    buscacaminos = Image.open("buscacaminos.jpg")
    buscacaminos = buscacaminos.resize((300, 300), Image.LANCZOS)
    buscacaminos = ImageTk.PhotoImage(buscacaminos)
    label_graf.configure(image=buscacaminos)
    label_graf.image = buscacaminos
    ocultar_botones()
    mostrar_botones34()

def mostrar_botones15():
    # Mostrar los botones para seleccionar el algoritmo de busqueda informado JUEGO 1 ROMPECOCOS
    Metodo1.pack(side="left", padx=50)
    Metodo2.pack(side="right", padx=50)

def mostrar_botones34():
    # Mostrar los botones para seleccionar el algoritmo de busqueda informado JUEGO 2 BUSCA CAMINOS
    Metodo3.pack(side="left", padx=50)
    Metodo4.pack(side="right", padx=50)

def ocultar_botones():
    # Ocultar los botones para seleccionar el algoritmo de busqueda informado
    Metodo1.pack_forget()
    Metodo2.pack_forget()
    Metodo3.pack_forget()
    Metodo4.pack_forget()

#---------------------------------------------------------------------------------------------------------------------------------------------------------------

# METODOS DE BUSQUEDA INFORMADOS

#---------------------------------------------------------------------------------------------------------------------------------------------------------------

def create_initial_state(input_string):
    try:
        numbers = [int(num) for num in input_string.split(",")]
        initialState = []
        for i in range(0, len(numbers), 3):
            row = numbers[i:i + 3]
            initialState.append(row)
        return initialState
    except ValueError:
        return None

# METODO 1 A*

""" 
#Mostrar los movimientos en la ventana
        for movimiento, estado in enumerate(movimientos, start=1):
            resultado.insert(tk.END, f"----------- MOVIMIENTO {movimiento} -----------\n")
            for fila in estado:
                resultado.insert(tk.END, " ".join(map(str, fila)))
                resultado.insert(tk.END, "\n")
            resultado.insert(tk.END, "\n")
"""

def metodo1():

    def correMetodo1():
        # Obtener los datos de entrada tableroInicial es una lista de listas de enteros, validar eso
        tableroInicial = TableroInicial.get()
        tableroInicial = create_initial_state(tableroInicial)
        resultado.delete(1.0, tk.END)
        resultado.insert(tk.END, "ROMPECOCOS: A*\n\n")
        start_time = time.perf_counter_ns()
        movimientos, solucion = rompecocosSolver.astarSolver(tableroInicial)
        astarSolverTime = (time.perf_counter_ns() - start_time) * 1e-9
        #Mostrar los movimientos en la ventana
        for movimiento, estado in enumerate(movimientos, start=1):
            resultado.insert(tk.END, f"----------- MOVIMIENTO {movimiento} -----------\n")
            for fila in estado:
                resultado.insert(tk.END, " ".join(map(str, fila)))
                resultado.insert(tk.END, "\n")
            resultado.insert(tk.END, "\n")
        resultado.insert(tk.END, f"Solucion: {len(movimientos)} movimientos\n\n")
        resultado.insert(tk.END, "----------- SOLUCIÓN ----------\n")
        for fila in solucion:
            resultado.insert(tk.END, " ".join(map(str, fila)))
            resultado.insert(tk.END, "\n\n")
        resultado.insert(tk.END, f"Time: {astarSolverTime} seconds\n")
        resultado.insert(tk.END, "\n")


    # NUEVA VENTANA
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    # Abrir una nueva ventana para realizar el metodo 1
    ventana1 = tk.Toplevel(window)
    ventana1.title("Metodo 1")
    ventana1.geometry("1920x1080")
    ventana1.configure(bg="#000000")
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

    # DATOS DE ENTRADA
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    # Frame de ingreso de datos
    frame = tk.Frame(ventana1, bg="#000000")
    frame.pack(pady=10)
    # Label para ingresar el dato1
    label1 = tk.Label(frame, text="Tablero Inicial:", font=("Impact", 15), bg="#000000", fg="#F7F7F7")
    label1.pack(side="left")
    # Entrada para ingresar el dato1 tableroInicial es una lista de listas de enteros, validar eso
    TableroInicial = tk.Entry(frame, font=("Impact", 15), bg="#F7F7F7", fg="#000000")
    TableroInicial.pack(side="left", padx=10)
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

    # BOTON DE EJECUCION
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    # Frame para el boton de ejecutar
    frame2 = tk.Frame(ventana1, bg="#000000")
    frame2.pack(pady=20)
    # Boton para ejecutar el metodo 1
    ejecutarM1 = tk.Button(frame2, text="Ejecutar", font=("Impact", 20), bg="#F7F7F7", fg="#000000")
    ejecutarM1.pack()
    ejecutarM1.config(command=lambda: correMetodo1())
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

    # RESULTADO
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    # Frame para mostrar el resultado
    frame3 = tk.Frame(ventana1, bg="#000000")
    frame3.pack(pady=20)
    # Hacer Scrollbar para mostrar el resultado
    scrollbar = tk.Scrollbar(frame3)
    scrollbar.pack(side="right", fill="y")
    resultado = tk.Text(frame3, width=50, height=10, yscrollcommand=scrollbar.set, font=("Impact", 15), bg="#F7F7F7", fg="#000000")
    resultado.pack()
    scrollbar.config(command=resultado.yview)
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

    # BOTON DE REGRESO
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    # Frame para el boton de regresar
    frame4 = tk.Frame(ventana1, bg="#000000")
    frame4.pack(side="left", pady=20, padx=20)
    # Boton para regresar a la ventana principal
    regresar = tk.Button(frame4, text="<", font=("Impact", 20), bg="#F7F7F7", fg="#000000")
    regresar.pack(side="left" ,padx=10)
    regresar.config(command=lambda: ventana1.destroy())
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    

# METODO 2 BEAM SEARCH
def metodo2():

    def correMetodo2():
        # Obtener los datos de entrada
        tableroInicial = TableroInicial.get()
        tableroInicial = create_initial_state(tableroInicial)
        k = K.get()
        resultado.delete(1.0, tk.END)
        resultado.insert(tk.END, "ROMPECOCOS: BEAM SEARCH\n\n")
        start_time = time.perf_counter_ns()
        movimientos, solucion = rompecocosSolver.beamSearch(tableroInicial, int(k))
        beamSearchSolverTime = (time.perf_counter_ns() - start_time) * 1e-9
        #Mostrar los movimientos en la ventana
        for movimiento, estado in enumerate(movimientos, start=1):
            resultado.insert(tk.END, f"----------- MOVIMIENTO {movimiento} -----------\n")
            for fila in estado:
                resultado.insert(tk.END, " ".join(map(str, fila)))
                resultado.insert(tk.END, "\n")
            resultado.insert(tk.END, "\n")
        resultado.insert(tk.END, f"Solucion: {len(movimientos)} movimientos\n\n")
        resultado.insert(tk.END, "----------- SOLUCIÓN ----------\n")
        for fila in solucion:
            resultado.insert(tk.END, " ".join(map(str, fila)))
            resultado.insert(tk.END, "\n\n")
        resultado.insert(tk.END, f"Time: {beamSearchSolverTime} seconds\n")
        resultado.insert(tk.END, "\n")

    # NUEVA VENTANA
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    # Abrir una nueva ventana para realizar el metodo 2
    ventana2 = tk.Toplevel(window)
    ventana2.title("Metodo 2")
    ventana2.geometry("1920x1080")
    ventana2.configure(bg="#000000")
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

    # DATOS DE ENTRADA
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    # Frame de ingreso de datos
    frame = tk.Frame(ventana2, bg="#000000")
    frame.pack(pady=10)
    # Label para ingresar el dato1
    label1 = tk.Label(frame, text="Tablero Inicial:", font=("Impact", 15), bg="#000000", fg="#F7F7F7")
    label1.pack(side="left")
    # Entrada para ingresar el dato1
    TableroInicial = tk.Entry(frame, font=("Impact", 15), bg="#F7F7F7", fg="#000000")
    TableroInicial.pack(side="left", padx=10)
    # Label para ingresar el dato2
    label2 = tk.Label(frame, text="K:", font=("Impact", 15), bg="#000000", fg="#F7F7F7")
    label2.pack(side="left")
    # Entrada para ingresar el dato2
    K = tk.Entry(frame, font=("Impact", 15), bg="#F7F7F7", fg="#000000")
    K.pack(side="left", padx=10)
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

    # BOTON DE EJECUCION
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    # Frame para el boton de ejecutar
    frame2 = tk.Frame(ventana2, bg="#000000")
    frame2.pack(pady=20)
    # Boton para ejecutar el metodo 2
    ejecutarM2 = tk.Button(frame2, text="Ejecutar", font=("Impact", 20), bg="#F7F7F7", fg="#000000")
    ejecutarM2.pack()
    ejecutarM2.config(command=lambda: correMetodo2())
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

    # RESULTADO
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    # Frame para mostrar el resultado
    frame3 = tk.Frame(ventana2, bg="#000000")
    frame3.pack(pady=20)
    # Hacer Scrollbar para mostrar el resultado
    scrollbar = tk.Scrollbar(frame3)
    scrollbar.pack(side="right", fill="y")
    resultado = tk.Text(frame3, width=50, height=10, yscrollcommand=scrollbar.set, font=("Impact", 15), bg="#F7F7F7", fg="#000000")
    resultado.pack()
    scrollbar.config(command=resultado.yview)
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

    # BOTON DE REGRESO
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    # Frame para el boton de regresar
    frame4 = tk.Frame(ventana2, bg="#000000")
    frame4.pack(side="left", pady=20, padx=20)
    # Boton para regresar a la ventana principal
    regresar = tk.Button(frame4, text="<", font=("Impact", 20), bg="#F7F7F7", fg="#000000")
    regresar.pack(side="left" ,padx=10)
    regresar.config(command=lambda: ventana2.destroy())
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# METODO 3 A*

def metodo3():

    def correMetodo3():
        # Obtener los datos de entrada
        letraInicio = LetraInicio.get()
        letraFinal = LetraFinal.get()
        obstaculos = Obstaculos.get()
        resultado.delete(1.0, tk.END)
        resultado.insert(tk.END, "BUSCA CAMINOS: A*\n\n")
        start_time = time.perf_counter_ns()
        path, cost, moves, steps = buscaCaminosSolver.astar(buscaCaminosSolver.grid, buscaCaminosSolver.locations[letraInicio], buscaCaminosSolver.locations[letraFinal], obstaculos)
        astarSolverTime = (time.perf_counter_ns() - start_time) * 1e-9
        # Mostrar todos los nodos visitados con letras y flechas, no con coordenadas
        for step in steps:
            for key, value in buscaCaminosSolver.locations.items():
                if value == step:
                    if key == letraFinal:
                        resultado.insert(tk.END, f"{key}\n")
                    else:
                        resultado.insert(tk.END, f"{key} -> ")
        #Mostrar el camino en la ventana con las letras y flechas, no con coordenadas
        for node in path:
            for key, value in buscaCaminosSolver.locations.items():
                if value == node:
                    if key == letraFinal:
                        resultado.insert(tk.END, f"{key}\n")
                    else:
                        resultado.insert(tk.END, f"{key} -> ")
        resultado.insert(tk.END, f"Cost: {cost}\n")
        resultado.insert(tk.END, f"Moves: {moves}\n")
        resultado.insert(tk.END, f"Time: {astarSolverTime} seconds\n")
        resultado.insert(tk.END, "\n")


    # NUEVA VENTANA
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    # Abrir una nueva ventana para realizar el metodo 3
    ventana3 = tk.Toplevel(window)
    ventana3.title("Metodo 3")
    ventana3.geometry("1920x1080")
    ventana3.configure(bg="#000000")
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

    # DATOS DE ENTRADA
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    # Frame de ingreso de datos
    frame = tk.Frame(ventana3, bg="#000000")
    frame.pack(pady=20)
    # Label para ingresar el dato1
    label1 = tk.Label(frame, text="Letra Inicio:", font=("Impact", 15), bg="#000000", fg="#F7F7F7")
    label1.pack(side="left")
    # Entrada para ingresar el dato1
    LetraInicio = tk.Entry(frame, font=("Impact", 15), bg="#F7F7F7", fg="#000000")
    LetraInicio.pack(side="left", padx=10)
    # Label para ingresar el dato2
    label2 = tk.Label(frame, text="Letra Objetivo:", font=("Impact", 15), bg="#000000", fg="#F7F7F7")
    label2.pack(side="left")
    # Entrada para ingresar el dato2
    LetraFinal = tk.Entry(frame, font=("Impact", 15), bg="#F7F7F7", fg="#000000")
    LetraFinal.pack(side="left", padx=10)
    # Label para ingresar el dato3
    label3 = tk.Label(frame, text="Obstaculos:", font=("Impact", 15), bg="#000000", fg="#F7F7F7")
    label3.pack(side="left")
    # Entrada para ingresar el dato3
    Obstaculos = tk.Entry(frame, font=("Impact", 15), bg="#F7F7F7", fg="#000000")
    Obstaculos.pack(side="left", padx=10)
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

    # BOTON DE EJECUCION
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    # Frame para el boton de ejecutar
    frame2 = tk.Frame(ventana3, bg="#000000")
    frame2.pack(pady=20)
    # Boton para ejecutar el metodo 3
    ejecutarM3 = tk.Button(frame2, text="Ejecutar", font=("Impact", 20), bg="#F7F7F7", fg="#000000")
    ejecutarM3.pack()
    ejecutarM3.config(command=lambda: correMetodo3())
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

    # RESULTADO
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    # Frame para mostrar el resultado
    frame3 = tk.Frame(ventana3, bg="#000000")
    frame3.pack(pady=20)
    # Hacer Scrollbar para mostrar el resultado
    scrollbar = tk.Scrollbar(frame3)
    scrollbar.pack(side="right", fill="y")
    resultado = tk.Text(frame3, width=50, height=10, yscrollcommand=scrollbar.set, font=("Impact", 15), bg="#F7F7F7", fg="#000000")
    resultado.pack()
    scrollbar.config(command=resultado.yview)
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

    # BOTON DE REGRESO
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    # Frame para el boton de regresar
    frame4 = tk.Frame(ventana3, bg="#000000")
    frame4.pack(side="left", pady=20, padx=20)
    # Boton para regresar a la ventana principal
    regresar = tk.Button(frame4, text="<", font=("Impact", 20), bg="#F7F7F7", fg="#000000")
    regresar.pack(side="left" ,padx=10)
    regresar.config(command=lambda: ventana3.destroy())
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# METODO 4 BEAM SEARCH

def metodo4():

    def correMetodo4():
        # Obtener los datos de entrada
        letraInicio = LetraInicio.get()
        letraFinal = LetraFinal.get()
        k = K.get()
        obstaculos = Obstaculos.get()
        resultado.delete(1.0, tk.END)
        resultado.insert(tk.END, "BUSCA CAMINOS: BEAM SEARCH\n\n")
        start_time = time.perf_counter_ns()
        path, cost, moves, steps = buscaCaminosSolver.beamSearch(buscaCaminosSolver.grid, buscaCaminosSolver.locations[letraInicio], buscaCaminosSolver.locations[letraFinal], int(k), obstaculos)
        beamSearchSolverTime = (time.perf_counter_ns() - start_time) * 1e-9
        # Mostrar todos los nodos visitados con letras y flechas, no con coordenadas
        for step in steps:
            for key, value in buscaCaminosSolver.locations.items():
                if value == step:
                    if key == letraFinal:
                        resultado.insert(tk.END, f"{key}\n")
                    else:
                        resultado.insert(tk.END, f"{key} -> ")
        #Mostrar el camino en la ventana con las letras y flechas, no con coordenadas
        for node in path:
            for key, value in buscaCaminosSolver.locations.items():
                if value == node:
                    if key == letraFinal:
                        resultado.insert(tk.END, f"{key}\n")
                    else:
                        resultado.insert(tk.END, f"{key} -> ")
        resultado.insert(tk.END, f"Cost: {cost}\n")
        resultado.insert(tk.END, f"Moves: {moves}\n")
        resultado.insert(tk.END, f"Time: {beamSearchSolverTime} seconds\n")
        resultado.insert(tk.END, "\n")

    # NUEVA VENTANA
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    # Abrir una nueva ventana para realizar el metodo 4
    ventana4 = tk.Toplevel(window)
    ventana4.title("Metodo 4")
    ventana4.geometry("1920x1080")
    ventana4.configure(bg="#000000")
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

    # DATOS DE ENTRADA
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    # Frame de ingreso de datos
    frame = tk.Frame(ventana4, bg="#000000")
    frame.pack(pady=10)
    # Label para ingresar el dato1
    label1 = tk.Label(frame, text="Letra Inicio:", font=("Impact", 15), bg="#000000", fg="#F7F7F7")
    label1.pack(side="left")
    # Entrada para ingresar el dato1
    LetraInicio = tk.Entry(frame, font=("Impact", 15), bg="#F7F7F7", fg="#000000")
    LetraInicio.pack(side="left", padx=10)
    # Label para ingresar el dato2
    label2 = tk.Label(frame, text="Letra Objetivo:", font=("Impact", 15), bg="#000000", fg="#F7F7F7")
    label2.pack(side="left")
    # Entrada para ingresar el dato2
    LetraFinal = tk.Entry(frame, font=("Impact", 15), bg="#F7F7F7", fg="#000000")
    LetraFinal.pack(side="left", padx=10)
    # Label para ingresar el dato3
    label3 = tk.Label(frame, text="K:", font=("Impact", 15), bg="#000000", fg="#F7F7F7")
    label3.pack(side="left")
    # Entrada para ingresar el dato3
    K = tk.Entry(frame, font=("Impact", 15), bg="#F7F7F7", fg="#000000")
    K.pack(side="left", padx=10)
    # Label para ingresar el dato4
    label4 = tk.Label(frame, text="Obstaculos:", font=("Impact", 15), bg="#000000", fg="#F7F7F7")
    label4.pack(side="left")
    # Entrada para ingresar el dato3
    Obstaculos = tk.Entry(frame, font=("Impact", 15), bg="#F7F7F7", fg="#000000")
    Obstaculos.pack(side="left", padx=10)
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

    # BOTON DE EJECUCION
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~    
    # Frame para el boton de ejecutar
    frame2 = tk.Frame(ventana4, bg="#000000")
    frame2.pack(pady=20)
    # Boton para ejecutar el metodo 4
    ejecutarM4 = tk.Button(frame2, text="Ejecutar", font=("Impact", 20), bg="#F7F7F7", fg="#000000")
    ejecutarM4.pack()
    ejecutarM4.config(command=lambda: correMetodo4())
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

    # RESULTADO
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    # Frame para mostrar el resultado
    frame3 = tk.Frame(ventana4, bg="#000000")
    frame3.pack(pady=20)
    # Hacer Scrollbar para mostrar el resultado
    scrollbar = tk.Scrollbar(frame3)
    scrollbar.pack(side="right", fill="y")
    resultado = tk.Text(frame3, width=50, height=10, yscrollcommand=scrollbar.set, font=("Impact", 15), bg="#F7F7F7", fg="#000000")
    resultado.pack()
    scrollbar.config(command=resultado.yview)
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

    # BOTON DE REGRESO
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    # Frame para el boton de regresar
    frame4 = tk.Frame(ventana4, bg="#000000")
    frame4.pack(side="left", pady=20, padx=20)
    # Boton para regresar a la ventana principal
    regresar = tk.Button(frame4, text="<", font=("Impact", 20), bg="#F7F7F7", fg="#000000")
    regresar.pack(side="left" ,padx=10)
    regresar.config(command=lambda: ventana4.destroy())
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#---------------------------------------------------------------------------------------------------------------------------------------------------------------

## INTERFAZ GRAFICA

#---------------------------------------------------------------------------------------------------------------------------------------------------------------
# VENTANA PRINCIPAL
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
window = tk.Tk()
window.title("Ventana Principal")
window.configure(bg="#000000")
window.geometry("1920x1080")

# Título
title = tk.Label(window, text="ALGORITMOS DE BUSQUEDA INFORMADOS", font=("Impact", 50), bg="#000000", fg="#F7F7F7")
title.pack()
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# BOTONES PARA SELECCIONAR EL JUEGO
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Frame para los botones para seleccionar el juego "Rompecocos" y "Busca Caminos"
framejuego = tk.Frame(window, bg="#000000")
framejuego.pack(pady=30)
# Botones para seleccionar el juego "Rompecocos" y "Busca Caminos"
BotonRompecocos = tk.Button(framejuego, text="Rompecocos", font=("Impact", 20), bg="#F7F7F7", fg="#000000")
BotonRompecocos.pack(side="left", padx=100)
BotonRompecocos.config(command=mostrar_rompecocos)
BotonBuscaCaminos = tk.Button(framejuego, text="Busca Caminos", font=("Impact", 20), bg="#F7F7F7", fg="#000000")
BotonBuscaCaminos.pack(side="right", padx=100)
BotonBuscaCaminos.config(command=mostrar_buscacaminos)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# IMAGEN DEL JUEGO
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Label Para mostrar imagen del Juego
label_graf = tk.Label(window, bg="#000000")
label_graf.pack(pady=30)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# BOTONES PARA SELECCIONAR EL ALGORITMO DE BUSQUEDA INFORMADO
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Frame para los botones para seleccionar el algoritmo de busqueda informado
framealgoritmo = tk.Frame(window, bg="#000000")
framealgoritmo.pack(pady=30)
# Botones para seleccionar el algoritmo de busqueda informado
Metodo1 = tk.Button(framealgoritmo, text="A-STAR", font=("Impact", 20), bg="#F7F7F7", fg="#000000")
Metodo1.pack_forget()
Metodo1.config(command=metodo1)
Metodo2 = tk.Button(framealgoritmo, text="BEAM SEARCH", font=("Impact", 20), bg="#F7F7F7", fg="#000000")
Metodo2.pack_forget()
Metodo2.config(command=metodo2)
Metodo3 = tk.Button(framealgoritmo, text="A-STAR", font=("Impact", 20), bg="#F7F7F7", fg="#000000")
Metodo3.pack_forget()
Metodo3.config(command=metodo3)
Metodo4 = tk.Button(framealgoritmo, text="BEAM SEARCH", font=("Impact", 20), bg="#F7F7F7", fg="#000000")
Metodo4.pack_forget()
Metodo4.config(command=metodo4)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# Mostrar la ventana GUI
window.mainloop()

#---------------------------------------------------------------------------------------------------------------------------------------------------------------
